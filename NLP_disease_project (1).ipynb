# %%
# !pip3 install --upgrade pandas
# Out:
# Requirement already up-to-date: pandas in c:\users\varnika mulay\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied, skipping upgrade: tzdata>=2022.1 in c:\users\varnika mulay\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.20.3; python_version < "3.10" in c:\users\varnika mulay\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.8.2 in c:\users\varnika mulay\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in c:\users\varnika mulay\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\varnika mulay\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)

# %%
import pandas as pd
# Out:
# C:\Users\Varnika Mulay\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
medquad = pd.read_csv("C:/Users/Varnika Mulay/Downloads/medquad_2.csv")
medquad
# Out:
#                                                 question  \
# 0                               What is (are) Glaucoma ?
# 1                                 What causes Glaucoma ?
# 2                    What are the symptoms of Glaucoma ?
# 3                 What are the treatments for Glaucoma ?
# 4                         Who is at risk for Glaucoma? ?
# ...                                                  ...
# 14344  What are the symptoms of Diabetic Neuropathies...
# 14345  How to prevent Diabetic Neuropathies: The Nerv...
# 14346  How to diagnose Diabetic Neuropathies: The Ner...
# 14347  What are the treatments for Diabetic Neuropath...
# 14348  What to do for Diabetic Neuropathies: The Nerv...
#
#                                                   answer           source  \
# 0      Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1      Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2      Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3      Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4      Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# ...                                                  ...              ...
# 14344  Symptoms depend on the type of neuropathy and ...            NIDDK
# 14345  The best way to prevent neuropathy is to keep ...            NIDDK
# 14346  Doctors diagnose neuropathy on the basis of sy...            NIDDK
# 14347  The first treatment step is to bring blood glu...            NIDDK
# 14348                                             #NAME?            NIDDK
#
#                                               focus_area
# 0                                               Glaucoma
# 1                                               Glaucoma
# 2                                               Glaucoma
# 3                                               Glaucoma
# 4                                               Glaucoma
# ...                                                  ...
# 14344  Diabetic Neuropathies: The Nerve Damage of Dia...
# 14345  Diabetic Neuropathies: The Nerve Damage of Dia...
# 14346  Diabetic Neuropathies: The Nerve Damage of Dia...
# 14347  Diabetic Neuropathies: The Nerve Damage of Dia...
# 14348  Diabetic Neuropathies: The Nerve Damage of Dia...
#
# [14349 rows x 4 columns]

# %% [markdown]
# # Preprocessing

# %%
medquad.isnull().sum()
# Out:
# question       0
# answer         4
# source         0
# focus_area    13
# dtype: int64

# %%
new_data = medquad.dropna(axis = 0, how ='any')  
new_data
# Out:
#                                                 question  \
# 0                               What is (are) Glaucoma ?
# 1                                 What causes Glaucoma ?
# 2                    What are the symptoms of Glaucoma ?
# 3                 What are the treatments for Glaucoma ?
# 4                         Who is at risk for Glaucoma? ?
# ...                                                  ...
# 14344  What are the symptoms of Diabetic Neuropathies...
# 14345  How to prevent Diabetic Neuropathies: The Nerv...
# 14346  How to diagnose Diabetic Neuropathies: The Ner...
# 14347  What are the treatments for Diabetic Neuropath...
# 14348  What to do for Diabetic Neuropathies: The Nerv...
#
#                                                   answer           source  \
# 0      Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1      Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2      Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3      Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4      Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# ...                                                  ...              ...
# 14344  Symptoms depend on the type of neuropathy and ...            NIDDK
# 14345  The best way to prevent neuropathy is to keep ...            NIDDK
# 14346  Doctors diagnose neuropathy on the basis of sy...            NIDDK
# 14347  The first treatment step is to bring blood glu...            NIDDK
# 14348                                             #NAME?            NIDDK
#
#                                               focus_area
# 0                                               Glaucoma
# 1                                               Glaucoma
# 2                                               Glaucoma
# 3                                               Glaucoma
# 4                                               Glaucoma
# ...                                                  ...
# 14344  Diabetic Neuropathies: The Nerve Damage of Dia...
# 14345  Diabetic Neuropathies: The Nerve Damage of Dia...
# 14346  Diabetic Neuropathies: The Nerve Damage of Dia...
# 14347  Diabetic Neuropathies: The Nerve Damage of Dia...
# 14348  Diabetic Neuropathies: The Nerve Damage of Dia...
#
# [14332 rows x 4 columns]

# %%
new_data.isnull().sum()
# Out:
# question      0
# answer        0
# source        0
# focus_area    0
# dtype: int64

# %%
new_data['focus_area'].unique()
# Out:
# array(['Glaucoma', 'High Blood Pressure', "Paget's Disease of Bone", ...,
#        'Microscopic Colitis: Collagenous Colitis and Lymphocytic Colitis',
#        'Cyclic Vomiting Syndrome',
#        'Diabetic Neuropathies: The Nerve Damage of Diabetes'],
#       dtype=object)

# %% [markdown]
# # For glaucoma and High BP

# %%
#For glaucoma
df_glaucoma = new_data.loc[new_data['focus_area'] == 'Glaucoma']
df_glaucoma
# Out:
#                                             question  \
# 0                           What is (are) Glaucoma ?
# 1                             What causes Glaucoma ?
# 2                What are the symptoms of Glaucoma ?
# 3             What are the treatments for Glaucoma ?
# 4                     Who is at risk for Glaucoma? ?
# 5                          How to prevent Glaucoma ?
# 6  what research (or clinical trials) is being do...
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# 5  At this time, we do not know how to prevent gl...  NIHSeniorHealth
# 6  Through studies in the laboratory and with pat...  NIHSeniorHealth
#
#   focus_area
# 0   Glaucoma
# 1   Glaucoma
# 2   Glaucoma
# 3   Glaucoma
# 4   Glaucoma
# 5   Glaucoma
# 6   Glaucoma

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
import nltk

# %%
df_glaucoma['combine'] = df_glaucoma['question'] + ' ' + df_glaucoma['answer']
df_glaucoma
# Out:
# <ipython-input-10-046b906510eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_glaucoma['combine'] = df_glaucoma['question'] + ' ' + df_glaucoma['answer']
#                                             question  \
# 0                           What is (are) Glaucoma ?
# 1                             What causes Glaucoma ?
# 2                What are the symptoms of Glaucoma ?
# 3             What are the treatments for Glaucoma ?
# 4                     Who is at risk for Glaucoma? ?
# 5                          How to prevent Glaucoma ?
# 6  what research (or clinical trials) is being do...
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# 5  At this time, we do not know how to prevent gl...  NIHSeniorHealth
# 6  Through studies in the laboratory and with pat...  NIHSeniorHealth
#
#   focus_area                                            combine
# 0   Glaucoma  What is (are) Glaucoma ? Glaucoma is a group o...
# 1   Glaucoma  What causes Glaucoma ? Nearly 2.7 million peop...
# 2   Glaucoma  What are the symptoms of Glaucoma ? Symptoms o...
# 3   Glaucoma  What are the treatments for Glaucoma ? Althoug...
# 4   Glaucoma  Who is at risk for Glaucoma? ? Anyone can deve...
# 5   Glaucoma  How to prevent Glaucoma ? At this time, we do ...
# 6   Glaucoma  what research (or clinical trials) is being do...

# %%
nltk.download('punkt'); '''punkt is a sentence tokenizer that takes a sentence of words and breaks 
them up into individual values.'''
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Varnika
# [nltk_data]     Mulay\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 'punkt is a sentence tokenizer that takes a sentence of words and breaks \nthem up into individual values.'

# %%
def tokenize(column):
    """Tokenizes a Pandas dataframe column and returns a list of tokens.

    Args:
        column: Pandas dataframe column (i.e. df['text']).

    Returns:
        tokens (list): Tokenized list, i.e. [Donald, Trump, tweets]
    """

    tokens = nltk.word_tokenize(column)
    return [w for w in tokens if w.isalpha()]

# %%
#tokenization
df_glaucoma['glaucoma_info'] = df_glaucoma.apply(lambda x: tokenize(x['combine']), axis=1)
df_glaucoma[['glaucoma_info']]
# Out:
# <ipython-input-13-7e0597dc0282>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_glaucoma['glaucoma_info'] = df_glaucoma.apply(lambda x: tokenize(x['combine']), axis=1)
#                                        glaucoma_info
# 0  [What, is, are, Glaucoma, Glaucoma, is, a, gro...
# 1  [What, causes, Glaucoma, Nearly, million, peop...
# 2  [What, are, the, symptoms, of, Glaucoma, Sympt...
# 3  [What, are, the, treatments, for, Glaucoma, Al...
# 4  [Who, is, at, risk, for, Glaucoma, Anyone, can...
# 5  [How, to, prevent, Glaucoma, At, this, time, w...
# 6  [what, research, or, clinical, trials, is, bei...

# %%
#stopword removal
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Varnika
# [nltk_data]     Mulay\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
# Function to remove stopwords
def remove_stopwords(text):
    stop_words = set(stopwords.words("english"))
    filtered_text = [word for word in text if word.lower() not in stop_words]
    return filtered_text

# Apply stopwords removal to the 'Text' column
df_glaucoma['glaucoma_info'] = df_glaucoma['glaucoma_info'].apply(remove_stopwords)

# Display the modified DataFrame
df_glaucoma['glaucoma_info']
# Out:
# <ipython-input-15-444f6eec3d48>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_glaucoma['glaucoma_info'] = df_glaucoma['glaucoma_info'].apply(remove_stopwords)
# 0    [Glaucoma, Glaucoma, group, diseases, damage, ...
# 1    [causes, Glaucoma, Nearly, million, people, gl...
# 2    [symptoms, Glaucoma, Symptoms, Glaucoma, Glauc...
# 3    [treatments, Glaucoma, Although, glaucoma, cur...
# 4    [risk, Glaucoma, Anyone, develop, glaucoma, pe...
# 5    [prevent, Glaucoma, time, know, prevent, glauc...
# 6    [research, clinical, trials, done, Glaucoma, s...
# Name: glaucoma_info, dtype: object

# %%
df_glaucoma
# Out:
#                                             question  \
# 0                           What is (are) Glaucoma ?
# 1                             What causes Glaucoma ?
# 2                What are the symptoms of Glaucoma ?
# 3             What are the treatments for Glaucoma ?
# 4                     Who is at risk for Glaucoma? ?
# 5                          How to prevent Glaucoma ?
# 6  what research (or clinical trials) is being do...
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# 5  At this time, we do not know how to prevent gl...  NIHSeniorHealth
# 6  Through studies in the laboratory and with pat...  NIHSeniorHealth
#
#   focus_area                                            combine  \
# 0   Glaucoma  What is (are) Glaucoma ? Glaucoma is a group o...
# 1   Glaucoma  What causes Glaucoma ? Nearly 2.7 million peop...
# 2   Glaucoma  What are the symptoms of Glaucoma ? Symptoms o...
# 3   Glaucoma  What are the treatments for Glaucoma ? Althoug...
# 4   Glaucoma  Who is at risk for Glaucoma? ? Anyone can deve...
# 5   Glaucoma  How to prevent Glaucoma ? At this time, we do ...
# 6   Glaucoma  what research (or clinical trials) is being do...
#
#                                        glaucoma_info
# 0  [Glaucoma, Glaucoma, group, diseases, damage, ...
# 1  [causes, Glaucoma, Nearly, million, people, gl...
# 2  [symptoms, Glaucoma, Symptoms, Glaucoma, Glauc...
# 3  [treatments, Glaucoma, Although, glaucoma, cur...
# 4  [risk, Glaucoma, Anyone, develop, glaucoma, pe...
# 5  [prevent, Glaucoma, time, know, prevent, glauc...
# 6  [research, clinical, trials, done, Glaucoma, s...

# %%
# Convert "glaucoma_info" to string
df_glaucoma = df_glaucoma.astype({'glaucoma_info':'string'})

# %%
import nltk

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

df_glaucoma['glaucoma_lemmatized'] = df_glaucoma.glaucoma_info.apply(lemmatize_text)
print(df_glaucoma)
# Out:
#                                             question  \
# 0                           What is (are) Glaucoma ?
# 1                             What causes Glaucoma ?
# 2                What are the symptoms of Glaucoma ?
# 3             What are the treatments for Glaucoma ?
# 4                     Who is at risk for Glaucoma? ?
# 5                          How to prevent Glaucoma ?
# 6  what research (or clinical trials) is being do...
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# 5  At this time, we do not know how to prevent gl...  NIHSeniorHealth
# 6  Through studies in the laboratory and with pat...  NIHSeniorHealth
#
#   focus_area                                            combine  \
# 0   Glaucoma  What is (are) Glaucoma ? Glaucoma is a group o...
# 1   Glaucoma  What causes Glaucoma ? Nearly 2.7 million peop...
# 2   Glaucoma  What are the symptoms of Glaucoma ? Symptoms o...
# 3   Glaucoma  What are the treatments for Glaucoma ? Althoug...
# 4   Glaucoma  Who is at risk for Glaucoma? ? Anyone can deve...
# 5   Glaucoma  How to prevent Glaucoma ? At this time, we do ...
# 6   Glaucoma  what research (or clinical trials) is being do...
#
#                                        glaucoma_info  \
# 0  ['Glaucoma', 'Glaucoma', 'group', 'diseases', ...
# 1  ['causes', 'Glaucoma', 'Nearly', 'million', 'p...
# 2  ['symptoms', 'Glaucoma', 'Symptoms', 'Glaucoma...
# 3  ['treatments', 'Glaucoma', 'Although', 'glauco...
# 4  ['risk', 'Glaucoma', 'Anyone', 'develop', 'gla...
# 5  ['prevent', 'Glaucoma', 'time', 'know', 'preve...
# 6  ['research', 'clinical', 'trials', 'done', 'Gl...
#
#                                  glaucoma_lemmatized
# 0  [['Glaucoma',, 'Glaucoma',, 'group',, 'disease...
# 1  [['causes',, 'Glaucoma',, 'Nearly',, 'million'...
# 2  [['symptoms',, 'Glaucoma',, 'Symptoms',, 'Glau...
# 3  [['treatments',, 'Glaucoma',, 'Although',, 'gl...
# 4  [['risk',, 'Glaucoma',, 'Anyone',, 'develop',,...
# 5  [['prevent',, 'Glaucoma',, 'time',, 'know',, '...
# 6  [['research',, 'clinical',, 'trials',, 'done',...

# %%
#df_glaucoma = df_glaucoma.drop(['glaucoma_info'], axis=1)

# %%
df_glaucoma
# Out:
#                                             question  \
# 0                           What is (are) Glaucoma ?
# 1                             What causes Glaucoma ?
# 2                What are the symptoms of Glaucoma ?
# 3             What are the treatments for Glaucoma ?
# 4                     Who is at risk for Glaucoma? ?
# 5                          How to prevent Glaucoma ?
# 6  what research (or clinical trials) is being do...
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# 5  At this time, we do not know how to prevent gl...  NIHSeniorHealth
# 6  Through studies in the laboratory and with pat...  NIHSeniorHealth
#
#   focus_area                                            combine  \
# 0   Glaucoma  What is (are) Glaucoma ? Glaucoma is a group o...
# 1   Glaucoma  What causes Glaucoma ? Nearly 2.7 million peop...
# 2   Glaucoma  What are the symptoms of Glaucoma ? Symptoms o...
# 3   Glaucoma  What are the treatments for Glaucoma ? Althoug...
# 4   Glaucoma  Who is at risk for Glaucoma? ? Anyone can deve...
# 5   Glaucoma  How to prevent Glaucoma ? At this time, we do ...
# 6   Glaucoma  what research (or clinical trials) is being do...
#
#                                        glaucoma_info  \
# 0  ['Glaucoma', 'Glaucoma', 'group', 'diseases', ...
# 1  ['causes', 'Glaucoma', 'Nearly', 'million', 'p...
# 2  ['symptoms', 'Glaucoma', 'Symptoms', 'Glaucoma...
# 3  ['treatments', 'Glaucoma', 'Although', 'glauco...
# 4  ['risk', 'Glaucoma', 'Anyone', 'develop', 'gla...
# 5  ['prevent', 'Glaucoma', 'time', 'know', 'preve...
# 6  ['research', 'clinical', 'trials', 'done', 'Gl...
#
#                                  glaucoma_lemmatized
# 0  [['Glaucoma',, 'Glaucoma',, 'group',, 'disease...
# 1  [['causes',, 'Glaucoma',, 'Nearly',, 'million'...
# 2  [['symptoms',, 'Glaucoma',, 'Symptoms',, 'Glau...
# 3  [['treatments',, 'Glaucoma',, 'Although',, 'gl...
# 4  [['risk',, 'Glaucoma',, 'Anyone',, 'develop',,...
# 5  [['prevent',, 'Glaucoma',, 'time',, 'know',, '...
# 6  [['research',, 'clinical',, 'trials',, 'done',...

# %%
result_df = df_glaucoma.drop_duplicates(subset=['glaucoma_lemmatized'], keep='first')
print(result_df)
# Out:
#                                             question  \
# 0                           What is (are) Glaucoma ?
# 1                             What causes Glaucoma ?
# 2                What are the symptoms of Glaucoma ?
# 3             What are the treatments for Glaucoma ?
# 4                     Who is at risk for Glaucoma? ?
# 5                          How to prevent Glaucoma ?
# 6  what research (or clinical trials) is being do...
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# 5  At this time, we do not know how to prevent gl...  NIHSeniorHealth
# 6  Through studies in the laboratory and with pat...  NIHSeniorHealth
#
#   focus_area                                            combine  \
# 0   Glaucoma  What is (are) Glaucoma ? Glaucoma is a group o...
# 1   Glaucoma  What causes Glaucoma ? Nearly 2.7 million peop...
# 2   Glaucoma  What are the symptoms of Glaucoma ? Symptoms o...
# 3   Glaucoma  What are the treatments for Glaucoma ? Althoug...
# 4   Glaucoma  Who is at risk for Glaucoma? ? Anyone can deve...
# 5   Glaucoma  How to prevent Glaucoma ? At this time, we do ...
# 6   Glaucoma  what research (or clinical trials) is being do...
#
#                                        glaucoma_info  \
# 0  ['Glaucoma', 'Glaucoma', 'group', 'diseases', ...
# 1  ['causes', 'Glaucoma', 'Nearly', 'million', 'p...
# 2  ['symptoms', 'Glaucoma', 'Symptoms', 'Glaucoma...
# 3  ['treatments', 'Glaucoma', 'Although', 'glauco...
# 4  ['risk', 'Glaucoma', 'Anyone', 'develop', 'gla...
# 5  ['prevent', 'Glaucoma', 'time', 'know', 'preve...
# 6  ['research', 'clinical', 'trials', 'done', 'Gl...
#
#                                  glaucoma_lemmatized
# 0  [['Glaucoma',, 'Glaucoma',, 'group',, 'disease...
# 1  [['causes',, 'Glaucoma',, 'Nearly',, 'million'...
# 2  [['symptoms',, 'Glaucoma',, 'Symptoms',, 'Glau...
# 3  [['treatments',, 'Glaucoma',, 'Although',, 'gl...
# 4  [['risk',, 'Glaucoma',, 'Anyone',, 'develop',,...
# 5  [['prevent',, 'Glaucoma',, 'time',, 'know',, '...
# 6  [['research',, 'clinical',, 'trials',, 'done',...

# %%
# Convert the lists to strings
result_df['glaucoma_lemmatized'] = result_df['glaucoma_lemmatized'].apply(lambda x: ' '.join(x))

# %%
result_df['index'] = result_df.index
result_df
# Out:
#                                             question  \
# 0                           What is (are) Glaucoma ?
# 1                             What causes Glaucoma ?
# 2                What are the symptoms of Glaucoma ?
# 3             What are the treatments for Glaucoma ?
# 4                     Who is at risk for Glaucoma? ?
# 5                          How to prevent Glaucoma ?
# 6  what research (or clinical trials) is being do...
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Anyone can develop glaucoma. Some people are a...  NIHSeniorHealth
# 5  At this time, we do not know how to prevent gl...  NIHSeniorHealth
# 6  Through studies in the laboratory and with pat...  NIHSeniorHealth
#
#   focus_area                                            combine  \
# 0   Glaucoma  What is (are) Glaucoma ? Glaucoma is a group o...
# 1   Glaucoma  What causes Glaucoma ? Nearly 2.7 million peop...
# 2   Glaucoma  What are the symptoms of Glaucoma ? Symptoms o...
# 3   Glaucoma  What are the treatments for Glaucoma ? Althoug...
# 4   Glaucoma  Who is at risk for Glaucoma? ? Anyone can deve...
# 5   Glaucoma  How to prevent Glaucoma ? At this time, we do ...
# 6   Glaucoma  what research (or clinical trials) is being do...
#
#                                        glaucoma_info  \
# 0  ['Glaucoma', 'Glaucoma', 'group', 'diseases', ...
# 1  ['causes', 'Glaucoma', 'Nearly', 'million', 'p...
# 2  ['symptoms', 'Glaucoma', 'Symptoms', 'Glaucoma...
# 3  ['treatments', 'Glaucoma', 'Although', 'glauco...
# 4  ['risk', 'Glaucoma', 'Anyone', 'develop', 'gla...
# 5  ['prevent', 'Glaucoma', 'time', 'know', 'preve...
# 6  ['research', 'clinical', 'trials', 'done', 'Gl...
#
#                                  glaucoma_lemmatized  index
# 0  ['Glaucoma', 'Glaucoma', 'group', 'diseases', ...      0
# 1  ['causes', 'Glaucoma', 'Nearly', 'million', 'p...      1
# 2  ['symptoms', 'Glaucoma', 'Symptoms', 'Glaucoma...      2
# 3  ['treatments', 'Glaucoma', 'Although', 'glauco...      3
# 4  ['risk', 'Glaucoma', 'Anyone', 'develop', 'gla...      4
# 5  ['prevent', 'Glaucoma', 'time', 'know', 'preve...      5
# 6  ['research', 'clinical', 'trials', 'done', 'Gl...      6

# %%
#For high blood pressure
df_bp = new_data.loc[new_data['focus_area'] == 'High Blood Pressure']
df_bp
# Out:
#                                              question  \
# 7                 What is (are) High Blood Pressure ?
# 8                   What causes High Blood Pressure ?
# 9           Who is at risk for High Blood Pressure? ?
# 10               How to prevent High Blood Pressure ?
# 11     What are the symptoms of High Blood Pressure ?
# 12              How to diagnose High Blood Pressure ?
# 13  What are the treatments for High Blood Pressure ?
#
#                                                answer           source  \
# 7   High blood pressure is a common disease in whi...  NIHSeniorHealth
# 8   Changes in Body Functions Researchers continue...  NIHSeniorHealth
# 9   Not a Normal Part of Aging Nearly 1 in 3 Ameri...  NIHSeniorHealth
# 10  Steps You Can Take You can take steps to preve...  NIHSeniorHealth
# 11  High blood pressure is often called the "silen...  NIHSeniorHealth
# 12  If you are diagnosed with high blood pressure,...  NIHSeniorHealth
# 13  High blood pressure is treated with lifestyle ...  NIHSeniorHealth
#
#              focus_area
# 7   High Blood Pressure
# 8   High Blood Pressure
# 9   High Blood Pressure
# 10  High Blood Pressure
# 11  High Blood Pressure
# 12  High Blood Pressure
# 13  High Blood Pressure

# %%
df_bp['combine'] = df_bp['question'] + ' ' + df_bp['answer']
df_bp
# Out:
# <ipython-input-25-bfa960d8d06e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bp['combine'] = df_bp['question'] + ' ' + df_bp['answer']
#                                              question  \
# 7                 What is (are) High Blood Pressure ?
# 8                   What causes High Blood Pressure ?
# 9           Who is at risk for High Blood Pressure? ?
# 10               How to prevent High Blood Pressure ?
# 11     What are the symptoms of High Blood Pressure ?
# 12              How to diagnose High Blood Pressure ?
# 13  What are the treatments for High Blood Pressure ?
#
#                                                answer           source  \
# 7   High blood pressure is a common disease in whi...  NIHSeniorHealth
# 8   Changes in Body Functions Researchers continue...  NIHSeniorHealth
# 9   Not a Normal Part of Aging Nearly 1 in 3 Ameri...  NIHSeniorHealth
# 10  Steps You Can Take You can take steps to preve...  NIHSeniorHealth
# 11  High blood pressure is often called the "silen...  NIHSeniorHealth
# 12  If you are diagnosed with high blood pressure,...  NIHSeniorHealth
# 13  High blood pressure is treated with lifestyle ...  NIHSeniorHealth
#
#              focus_area                                            combine
# 7   High Blood Pressure  What is (are) High Blood Pressure ? High blood...
# 8   High Blood Pressure  What causes High Blood Pressure ? Changes in B...
# 9   High Blood Pressure  Who is at risk for High Blood Pressure? ? Not ...
# 10  High Blood Pressure  How to prevent High Blood Pressure ? Steps You...
# 11  High Blood Pressure  What are the symptoms of High Blood Pressure ?...
# 12  High Blood Pressure  How to diagnose High Blood Pressure ? If you a...
# 13  High Blood Pressure  What are the treatments for High Blood Pressur...

# %%
#tokenization
df_bp['bp_info'] = df_bp.apply(lambda x: tokenize(x['combine']), axis=1)
df_bp[['bp_info']]
# Out:
# <ipython-input-26-45012b28ae0b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bp['bp_info'] = df_bp.apply(lambda x: tokenize(x['combine']), axis=1)
#                                               bp_info
# 7   [What, is, are, High, Blood, Pressure, High, b...
# 8   [What, causes, High, Blood, Pressure, Changes,...
# 9   [Who, is, at, risk, for, High, Blood, Pressure...
# 10  [How, to, prevent, High, Blood, Pressure, Step...
# 11  [What, are, the, symptoms, of, High, Blood, Pr...
# 12  [How, to, diagnose, High, Blood, Pressure, If,...
# 13  [What, are, the, treatments, for, High, Blood,...

# %%
#stopword removal
from nltk.corpus import stopwords
# Function to remove stopwords
def remove_stopwords(text):
    stop_words = set(stopwords.words("english"))
    filtered_text = [word for word in text if word.lower() not in stop_words]
    return filtered_text

# Apply stopwords removal to the 'Text' column
df_bp['bp_info'] = df_bp['bp_info'].apply(remove_stopwords)

# Display the modified DataFrame
df_bp['bp_info']
# Out:
# <ipython-input-27-a21b1038f8a5>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bp['bp_info'] = df_bp['bp_info'].apply(remove_stopwords)
# 7     [High, Blood, Pressure, High, blood, pressure,...
# 8     [causes, High, Blood, Pressure, Changes, Body,...
# 9     [risk, High, Blood, Pressure, Normal, Part, Ag...
# 10    [prevent, High, Blood, Pressure, Steps, Take, ...
# 11    [symptoms, High, Blood, Pressure, High, blood,...
# 12    [diagnose, High, Blood, Pressure, diagnosed, h...
# 13    [treatments, High, Blood, Pressure, High, bloo...
# Name: bp_info, dtype: object

# %%
# Convert "bp_info" to string
df_bp = df_bp.astype({'bp_info':'string'})

# %%
import nltk

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

df_bp['bp_lemmatized'] = df_bp.bp_info.apply(lemmatize_text)
print(df_bp)
# Out:
#                                              question  \
# 7                 What is (are) High Blood Pressure ?
# 8                   What causes High Blood Pressure ?
# 9           Who is at risk for High Blood Pressure? ?
# 10               How to prevent High Blood Pressure ?
# 11     What are the symptoms of High Blood Pressure ?
# 12              How to diagnose High Blood Pressure ?
# 13  What are the treatments for High Blood Pressure ?
#
#                                                answer           source  \
# 7   High blood pressure is a common disease in whi...  NIHSeniorHealth
# 8   Changes in Body Functions Researchers continue...  NIHSeniorHealth
# 9   Not a Normal Part of Aging Nearly 1 in 3 Ameri...  NIHSeniorHealth
# 10  Steps You Can Take You can take steps to preve...  NIHSeniorHealth
# 11  High blood pressure is often called the "silen...  NIHSeniorHealth
# 12  If you are diagnosed with high blood pressure,...  NIHSeniorHealth
# 13  High blood pressure is treated with lifestyle ...  NIHSeniorHealth
#
#              focus_area                                            combine  \
# 7   High Blood Pressure  What is (are) High Blood Pressure ? High blood...
# 8   High Blood Pressure  What causes High Blood Pressure ? Changes in B...
# 9   High Blood Pressure  Who is at risk for High Blood Pressure? ? Not ...
# 10  High Blood Pressure  How to prevent High Blood Pressure ? Steps You...
# 11  High Blood Pressure  What are the symptoms of High Blood Pressure ?...
# 12  High Blood Pressure  How to diagnose High Blood Pressure ? If you a...
# 13  High Blood Pressure  What are the treatments for High Blood Pressur...
#
#                                               bp_info  \
# 7   ['High', 'Blood', 'Pressure', 'High', 'blood',...
# 8   ['causes', 'High', 'Blood', 'Pressure', 'Chang...
# 9   ['risk', 'High', 'Blood', 'Pressure', 'Normal'...
# 10  ['prevent', 'High', 'Blood', 'Pressure', 'Step...
# 11  ['symptoms', 'High', 'Blood', 'Pressure', 'Hig...
# 12  ['diagnose', 'High', 'Blood', 'Pressure', 'dia...
# 13  ['treatments', 'High', 'Blood', 'Pressure', 'H...
#
#                                         bp_lemmatized
# 7   [['High',, 'Blood',, 'Pressure',, 'High',, 'bl...
# 8   [['causes',, 'High',, 'Blood',, 'Pressure',, '...
# 9   [['risk',, 'High',, 'Blood',, 'Pressure',, 'No...
# 10  [['prevent',, 'High',, 'Blood',, 'Pressure',, ...
# 11  [['symptoms',, 'High',, 'Blood',, 'Pressure',,...
# 12  [['diagnose',, 'High',, 'Blood',, 'Pressure',,...
# 13  [['treatments',, 'High',, 'Blood',, 'Pressure'...

# %%
#df_bp = df_bp.drop(['bp_info'], axis=1)
df_bp
# Out:
#                                              question  \
# 7                 What is (are) High Blood Pressure ?
# 8                   What causes High Blood Pressure ?
# 9           Who is at risk for High Blood Pressure? ?
# 10               How to prevent High Blood Pressure ?
# 11     What are the symptoms of High Blood Pressure ?
# 12              How to diagnose High Blood Pressure ?
# 13  What are the treatments for High Blood Pressure ?
#
#                                                answer           source  \
# 7   High blood pressure is a common disease in whi...  NIHSeniorHealth
# 8   Changes in Body Functions Researchers continue...  NIHSeniorHealth
# 9   Not a Normal Part of Aging Nearly 1 in 3 Ameri...  NIHSeniorHealth
# 10  Steps You Can Take You can take steps to preve...  NIHSeniorHealth
# 11  High blood pressure is often called the "silen...  NIHSeniorHealth
# 12  If you are diagnosed with high blood pressure,...  NIHSeniorHealth
# 13  High blood pressure is treated with lifestyle ...  NIHSeniorHealth
#
#              focus_area                                            combine  \
# 7   High Blood Pressure  What is (are) High Blood Pressure ? High blood...
# 8   High Blood Pressure  What causes High Blood Pressure ? Changes in B...
# 9   High Blood Pressure  Who is at risk for High Blood Pressure? ? Not ...
# 10  High Blood Pressure  How to prevent High Blood Pressure ? Steps You...
# 11  High Blood Pressure  What are the symptoms of High Blood Pressure ?...
# 12  High Blood Pressure  How to diagnose High Blood Pressure ? If you a...
# 13  High Blood Pressure  What are the treatments for High Blood Pressur...
#
#                                               bp_info  \
# 7   ['High', 'Blood', 'Pressure', 'High', 'blood',...
# 8   ['causes', 'High', 'Blood', 'Pressure', 'Chang...
# 9   ['risk', 'High', 'Blood', 'Pressure', 'Normal'...
# 10  ['prevent', 'High', 'Blood', 'Pressure', 'Step...
# 11  ['symptoms', 'High', 'Blood', 'Pressure', 'Hig...
# 12  ['diagnose', 'High', 'Blood', 'Pressure', 'dia...
# 13  ['treatments', 'High', 'Blood', 'Pressure', 'H...
#
#                                         bp_lemmatized
# 7   [['High',, 'Blood',, 'Pressure',, 'High',, 'bl...
# 8   [['causes',, 'High',, 'Blood',, 'Pressure',, '...
# 9   [['risk',, 'High',, 'Blood',, 'Pressure',, 'No...
# 10  [['prevent',, 'High',, 'Blood',, 'Pressure',, ...
# 11  [['symptoms',, 'High',, 'Blood',, 'Pressure',,...
# 12  [['diagnose',, 'High',, 'Blood',, 'Pressure',,...
# 13  [['treatments',, 'High',, 'Blood',, 'Pressure'...

# %%
bp_result_df = df_bp.drop_duplicates(subset=['bp_lemmatized'], keep='first')
print(bp_result_df)
# Out:
#                                              question  \
# 7                 What is (are) High Blood Pressure ?
# 8                   What causes High Blood Pressure ?
# 9           Who is at risk for High Blood Pressure? ?
# 10               How to prevent High Blood Pressure ?
# 11     What are the symptoms of High Blood Pressure ?
# 12              How to diagnose High Blood Pressure ?
# 13  What are the treatments for High Blood Pressure ?
#
#                                                answer           source  \
# 7   High blood pressure is a common disease in whi...  NIHSeniorHealth
# 8   Changes in Body Functions Researchers continue...  NIHSeniorHealth
# 9   Not a Normal Part of Aging Nearly 1 in 3 Ameri...  NIHSeniorHealth
# 10  Steps You Can Take You can take steps to preve...  NIHSeniorHealth
# 11  High blood pressure is often called the "silen...  NIHSeniorHealth
# 12  If you are diagnosed with high blood pressure,...  NIHSeniorHealth
# 13  High blood pressure is treated with lifestyle ...  NIHSeniorHealth
#
#              focus_area                                            combine  \
# 7   High Blood Pressure  What is (are) High Blood Pressure ? High blood...
# 8   High Blood Pressure  What causes High Blood Pressure ? Changes in B...
# 9   High Blood Pressure  Who is at risk for High Blood Pressure? ? Not ...
# 10  High Blood Pressure  How to prevent High Blood Pressure ? Steps You...
# 11  High Blood Pressure  What are the symptoms of High Blood Pressure ?...
# 12  High Blood Pressure  How to diagnose High Blood Pressure ? If you a...
# 13  High Blood Pressure  What are the treatments for High Blood Pressur...
#
#                                               bp_info  \
# 7   ['High', 'Blood', 'Pressure', 'High', 'blood',...
# 8   ['causes', 'High', 'Blood', 'Pressure', 'Chang...
# 9   ['risk', 'High', 'Blood', 'Pressure', 'Normal'...
# 10  ['prevent', 'High', 'Blood', 'Pressure', 'Step...
# 11  ['symptoms', 'High', 'Blood', 'Pressure', 'Hig...
# 12  ['diagnose', 'High', 'Blood', 'Pressure', 'dia...
# 13  ['treatments', 'High', 'Blood', 'Pressure', 'H...
#
#                                         bp_lemmatized
# 7   [['High',, 'Blood',, 'Pressure',, 'High',, 'bl...
# 8   [['causes',, 'High',, 'Blood',, 'Pressure',, '...
# 9   [['risk',, 'High',, 'Blood',, 'Pressure',, 'No...
# 10  [['prevent',, 'High',, 'Blood',, 'Pressure',, ...
# 11  [['symptoms',, 'High',, 'Blood',, 'Pressure',,...
# 12  [['diagnose',, 'High',, 'Blood',, 'Pressure',,...
# 13  [['treatments',, 'High',, 'Blood',, 'Pressure'...

# %%
# Convert the lists to strings
bp_result_df['bp_lemmatized'] = bp_result_df['bp_lemmatized'].apply(lambda x: ' '.join(x))

# %%
bp_result_df['index'] = bp_result_df.index
bp_result_df
# Out:
#                                              question  \
# 7                 What is (are) High Blood Pressure ?
# 8                   What causes High Blood Pressure ?
# 9           Who is at risk for High Blood Pressure? ?
# 10               How to prevent High Blood Pressure ?
# 11     What are the symptoms of High Blood Pressure ?
# 12              How to diagnose High Blood Pressure ?
# 13  What are the treatments for High Blood Pressure ?
#
#                                                answer           source  \
# 7   High blood pressure is a common disease in whi...  NIHSeniorHealth
# 8   Changes in Body Functions Researchers continue...  NIHSeniorHealth
# 9   Not a Normal Part of Aging Nearly 1 in 3 Ameri...  NIHSeniorHealth
# 10  Steps You Can Take You can take steps to preve...  NIHSeniorHealth
# 11  High blood pressure is often called the "silen...  NIHSeniorHealth
# 12  If you are diagnosed with high blood pressure,...  NIHSeniorHealth
# 13  High blood pressure is treated with lifestyle ...  NIHSeniorHealth
#
#              focus_area                                            combine  \
# 7   High Blood Pressure  What is (are) High Blood Pressure ? High blood...
# 8   High Blood Pressure  What causes High Blood Pressure ? Changes in B...
# 9   High Blood Pressure  Who is at risk for High Blood Pressure? ? Not ...
# 10  High Blood Pressure  How to prevent High Blood Pressure ? Steps You...
# 11  High Blood Pressure  What are the symptoms of High Blood Pressure ?...
# 12  High Blood Pressure  How to diagnose High Blood Pressure ? If you a...
# 13  High Blood Pressure  What are the treatments for High Blood Pressur...
#
#                                               bp_info  \
# 7   ['High', 'Blood', 'Pressure', 'High', 'blood',...
# 8   ['causes', 'High', 'Blood', 'Pressure', 'Chang...
# 9   ['risk', 'High', 'Blood', 'Pressure', 'Normal'...
# 10  ['prevent', 'High', 'Blood', 'Pressure', 'Step...
# 11  ['symptoms', 'High', 'Blood', 'Pressure', 'Hig...
# 12  ['diagnose', 'High', 'Blood', 'Pressure', 'dia...
# 13  ['treatments', 'High', 'Blood', 'Pressure', 'H...
#
#                                         bp_lemmatized  index
# 7   ['High', 'Blood', 'Pressure', 'High', 'blood',...      7
# 8   ['causes', 'High', 'Blood', 'Pressure', 'Chang...      8
# 9   ['risk', 'High', 'Blood', 'Pressure', 'Normal'...      9
# 10  ['prevent', 'High', 'Blood', 'Pressure', 'Step...     10
# 11  ['symptoms', 'High', 'Blood', 'Pressure', 'Hig...     11
# 12  ['diagnose', 'High', 'Blood', 'Pressure', 'dia...     12
# 13  ['treatments', 'High', 'Blood', 'Pressure', 'H...     13

# %%
# Print rows with empty documents for glaucoma
print("Empty documents in glaucoma:")
print(result_df[result_df['glaucoma_lemmatized'].apply(lambda x: len(x)) == 0])

# Print rows with empty documents for bp
print("Empty documents in bp:")
print(bp_result_df[bp_result_df['bp_lemmatized'].apply(lambda x: len(x)) == 0])
# Out:
# Empty documents in glaucoma:
# Empty DataFrame
# Columns: [question, answer, source, focus_area, combine, glaucoma_info, glaucoma_lemmatized, index]
# Index: []
# Empty documents in bp:
# Empty DataFrame
# Columns: [question, answer, source, focus_area, combine, bp_info, bp_lemmatized, index]
# Index: []

# %%
glaucoma_final = pd.DataFrame(data = result_df['glaucoma_lemmatized'])
glaucoma_final
# Out:
#                                  glaucoma_lemmatized
# 0  ['Glaucoma', 'Glaucoma', 'group', 'diseases', ...
# 1  ['causes', 'Glaucoma', 'Nearly', 'million', 'p...
# 2  ['symptoms', 'Glaucoma', 'Symptoms', 'Glaucoma...
# 3  ['treatments', 'Glaucoma', 'Although', 'glauco...
# 4  ['risk', 'Glaucoma', 'Anyone', 'develop', 'gla...
# 5  ['prevent', 'Glaucoma', 'time', 'know', 'preve...
# 6  ['research', 'clinical', 'trials', 'done', 'Gl...

# %%
bp_final = pd.DataFrame(data = bp_result_df['bp_lemmatized'])
bp_final
# Out:
#                                         bp_lemmatized
# 7   ['High', 'Blood', 'Pressure', 'High', 'blood',...
# 8   ['causes', 'High', 'Blood', 'Pressure', 'Chang...
# 9   ['risk', 'High', 'Blood', 'Pressure', 'Normal'...
# 10  ['prevent', 'High', 'Blood', 'Pressure', 'Step...
# 11  ['symptoms', 'High', 'Blood', 'Pressure', 'Hig...
# 12  ['diagnose', 'High', 'Blood', 'Pressure', 'dia...
# 13  ['treatments', 'High', 'Blood', 'Pressure', 'H...

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Function to calculate Jaccard similarity
def jaccard_similarity(list1, list2):
    intersection = len(set(list1).intersection(list2))
    union = len(set(list1).union(list2))
    return intersection / union if union != 0 else 0

# Function to calculate Jaccard similarity between rows of two DataFrames
def calculate_similarity(df1, df2):
    similarities = []

    for index1, row1 in df1.iterrows():
        for index2, row2 in df2.iterrows():
            sim = jaccard_similarity(row1['glaucoma_lemmatized'], row2['bp_lemmatized'])
            similarities.append((index1, index2, sim))

    return similarities


similarities = calculate_similarity(glaucoma_final, bp_final)

# Displaying the results
for idx1, idx2, sim in similarities:
    print(f"Similarity between row {idx1} in glaucoma and row {idx2} in high bp: {sim}")
# Out:
# Similarity between row 0 in glaucoma and row 7 in high bp: 0.9019607843137255
# Similarity between row 0 in glaucoma and row 8 in high bp: 0.9215686274509803
# Similarity between row 0 in glaucoma and row 9 in high bp: 0.9
# Similarity between row 0 in glaucoma and row 10 in high bp: 0.9056603773584906
# Similarity between row 0 in glaucoma and row 11 in high bp: 0.7884615384615384
# Similarity between row 0 in glaucoma and row 12 in high bp: 0.88
# Similarity between row 0 in glaucoma and row 13 in high bp: 0.9411764705882353
# Similarity between row 1 in glaucoma and row 7 in high bp: 0.6938775510204082
# Similarity between row 1 in glaucoma and row 8 in high bp: 0.68
# Similarity between row 1 in glaucoma and row 9 in high bp: 0.7608695652173914
# Similarity between row 1 in glaucoma and row 10 in high bp: 0.6730769230769231
# Similarity between row 1 in glaucoma and row 11 in high bp: 0.717391304347826
# Similarity between row 1 in glaucoma and row 12 in high bp: 0.7777777777777778
# Similarity between row 1 in glaucoma and row 13 in high bp: 0.7346938775510204
# Similarity between row 2 in glaucoma and row 7 in high bp: 0.64
# Similarity between row 2 in glaucoma and row 8 in high bp: 0.66
# Similarity between row 2 in glaucoma and row 9 in high bp: 0.7021276595744681
# Similarity between row 2 in glaucoma and row 10 in high bp: 0.6862745098039216
# Similarity between row 2 in glaucoma and row 11 in high bp: 0.6956521739130435
# Similarity between row 2 in glaucoma and row 12 in high bp: 0.7555555555555555
# Similarity between row 2 in glaucoma and row 13 in high bp: 0.7142857142857143
# Similarity between row 3 in glaucoma and row 7 in high bp: 0.8
# Similarity between row 3 in glaucoma and row 8 in high bp: 0.82
# Similarity between row 3 in glaucoma and row 9 in high bp: 0.8333333333333334
# Similarity between row 3 in glaucoma and row 10 in high bp: 0.8076923076923077
# Similarity between row 3 in glaucoma and row 11 in high bp: 0.72
# Similarity between row 3 in glaucoma and row 12 in high bp: 0.8125
# Similarity between row 3 in glaucoma and row 13 in high bp: 0.84
# Similarity between row 4 in glaucoma and row 7 in high bp: 0.6875
# Similarity between row 4 in glaucoma and row 8 in high bp: 0.673469387755102
# Similarity between row 4 in glaucoma and row 9 in high bp: 0.717391304347826
# Similarity between row 4 in glaucoma and row 10 in high bp: 0.6666666666666666
# Similarity between row 4 in glaucoma and row 11 in high bp: 0.75
# Similarity between row 4 in glaucoma and row 12 in high bp: 0.7333333333333333
# Similarity between row 4 in glaucoma and row 13 in high bp: 0.66
# Similarity between row 5 in glaucoma and row 7 in high bp: 0.6458333333333334
# Similarity between row 5 in glaucoma and row 8 in high bp: 0.6326530612244898
# Similarity between row 5 in glaucoma and row 9 in high bp: 0.6739130434782609
# Similarity between row 5 in glaucoma and row 10 in high bp: 0.6274509803921569
# Similarity between row 5 in glaucoma and row 11 in high bp: 0.6304347826086957
# Similarity between row 5 in glaucoma and row 12 in high bp: 0.6888888888888889
# Similarity between row 5 in glaucoma and row 13 in high bp: 0.62
# Similarity between row 6 in glaucoma and row 7 in high bp: 0.6458333333333334
# Similarity between row 6 in glaucoma and row 8 in high bp: 0.6666666666666666
# Similarity between row 6 in glaucoma and row 9 in high bp: 0.6739130434782609
# Similarity between row 6 in glaucoma and row 10 in high bp: 0.6274509803921569
# Similarity between row 6 in glaucoma and row 11 in high bp: 0.6304347826086957
# Similarity between row 6 in glaucoma and row 12 in high bp: 0.6888888888888889
# Similarity between row 6 in glaucoma and row 13 in high bp: 0.6530612244897959

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a DataFrame from the list of similarities
similarity_df = pd.DataFrame(similarities, columns=['Index1', 'Index2', 'Similarity'])

# Reshape the DataFrame to create a similarity matrix
similarity_matrix = similarity_df.pivot(index='Index1', columns='Index2', values='Similarity')

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(similarity_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, cbar_kws={'label': 'Jaccard Similarity'})
plt.title('Glaucoma & High BP Similarity Heatmap')
plt.xlabel('High BP index')
plt.ylabel('Glaucoma index')
plt.show()

# %% [markdown]
# # From the above graph we can see that the highly correlated rows are:
# row 0 (glaucoma) and row 13 (high bp)\
# row 0 (glaucoma) and row 8 (high bp)\
# row 0 (glaucoma) and row 10 (high bp)\
# row 0 (glaucoma) and row 7 (high bp)\
# row 0 (glaucoma) and row 9 (high bp)\
# row 0 (glaucoma) and row 12 (high bp)\
# row 3 (glaucoma) and row 13 (high bp)

# %% [markdown]
# Hence, we can say that High BP and glaucoma are highly correlated and similar to each other. A patient having high BP has a high chance of developing glaucoma.

# %% [markdown]
# # For glaucoma and diabetes

# %%
#For diabetes
df_diabetes = new_data.loc[new_data['focus_area'] == 'Diabetes']
df_diabetes
# Out:
#                                   question  \
# 50                What is (are) Diabetes ?
# 51          Who is at risk for Diabetes? ?
# 52               How to prevent Diabetes ?
# 53     What are the symptoms of Diabetes ?
# 54  What are the treatments for Diabetes ?
# 55                  What causes Diabetes ?
#
#                                                answer           source  \
# 50  Too Much Glucose in the Blood Diabetes means y...  NIHSeniorHealth
# 51  Diabetes is a serious, life-long disease. It c...  NIHSeniorHealth
# 52  The two most common forms of diabetes are type...  NIHSeniorHealth
# 53  Diabetes is often called a "silent" disease be...  NIHSeniorHealth
# 54  Diabetes cannot be cured, but it can be manage...  NIHSeniorHealth
# 55  Type 1 diabetes is an autoimmune disease. In a...  NIHSeniorHealth
#
#    focus_area
# 50   Diabetes
# 51   Diabetes
# 52   Diabetes
# 53   Diabetes
# 54   Diabetes
# 55   Diabetes

# %%
df_diabetes['combine'] = df_diabetes['question'] + ' ' + df_diabetes['answer']
df_diabetes
# Out:
# <ipython-input-40-03b0e411cf58>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_diabetes['combine'] = df_diabetes['question'] + ' ' + df_diabetes['answer']
#                                   question  \
# 50                What is (are) Diabetes ?
# 51          Who is at risk for Diabetes? ?
# 52               How to prevent Diabetes ?
# 53     What are the symptoms of Diabetes ?
# 54  What are the treatments for Diabetes ?
# 55                  What causes Diabetes ?
#
#                                                answer           source  \
# 50  Too Much Glucose in the Blood Diabetes means y...  NIHSeniorHealth
# 51  Diabetes is a serious, life-long disease. It c...  NIHSeniorHealth
# 52  The two most common forms of diabetes are type...  NIHSeniorHealth
# 53  Diabetes is often called a "silent" disease be...  NIHSeniorHealth
# 54  Diabetes cannot be cured, but it can be manage...  NIHSeniorHealth
# 55  Type 1 diabetes is an autoimmune disease. In a...  NIHSeniorHealth
#
#    focus_area                                            combine
# 50   Diabetes  What is (are) Diabetes ? Too Much Glucose in t...
# 51   Diabetes  Who is at risk for Diabetes? ? Diabetes is a s...
# 52   Diabetes  How to prevent Diabetes ? The two most common ...
# 53   Diabetes  What are the symptoms of Diabetes ? Diabetes i...
# 54   Diabetes  What are the treatments for Diabetes ? Diabete...
# 55   Diabetes  What causes Diabetes ? Type 1 diabetes is an a...

# %%
#tokenization
df_diabetes['diabetes_info'] = df_diabetes.apply(lambda x: tokenize(x['combine']), axis=1)
df_diabetes[['diabetes_info']]
# Out:
# <ipython-input-41-8a77a7682c3e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_diabetes['diabetes_info'] = df_diabetes.apply(lambda x: tokenize(x['combine']), axis=1)
#                                         diabetes_info
# 50  [What, is, are, Diabetes, Too, Much, Glucose, ...
# 51  [Who, is, at, risk, for, Diabetes, Diabetes, i...
# 52  [How, to, prevent, Diabetes, The, two, most, c...
# 53  [What, are, the, symptoms, of, Diabetes, Diabe...
# 54  [What, are, the, treatments, for, Diabetes, Di...
# 55  [What, causes, Diabetes, Type, diabetes, is, a...

# %%
#stopword removal
from nltk.corpus import stopwords
# Function to remove stopwords
def remove_stopwords(text):
    stop_words = set(stopwords.words("english"))
    filtered_text = [word for word in text if word.lower() not in stop_words]
    return filtered_text

# Apply stopwords removal to the 'Text' column
df_diabetes['diabetes_info'] = df_diabetes['diabetes_info'].apply(remove_stopwords)

# Display the modified DataFrame
df_diabetes['diabetes_info']
# Out:
# <ipython-input-42-9fc582a4c8d1>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_diabetes['diabetes_info'] = df_diabetes['diabetes_info'].apply(remove_stopwords)
# 50    [Diabetes, Much, Glucose, Blood, Diabetes, mea...
# 51    [risk, Diabetes, Diabetes, serious, disease, l...
# 52    [prevent, Diabetes, two, common, forms, diabet...
# 53    [symptoms, Diabetes, Diabetes, often, called, ...
# 54    [treatments, Diabetes, Diabetes, cured, manage...
# 55    [causes, Diabetes, Type, diabetes, autoimmune,...
# Name: diabetes_info, dtype: object

# %%
# Convert "diabetes_info" to string
df_diabetes = df_diabetes.astype({'diabetes_info':'string'})

# %%
import nltk

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

df_diabetes['diabetes_lemmatized'] = df_diabetes.diabetes_info.apply(lemmatize_text)
print(df_diabetes)
# Out:
#                                   question  \
# 50                What is (are) Diabetes ?
# 51          Who is at risk for Diabetes? ?
# 52               How to prevent Diabetes ?
# 53     What are the symptoms of Diabetes ?
# 54  What are the treatments for Diabetes ?
# 55                  What causes Diabetes ?
#
#                                                answer           source  \
# 50  Too Much Glucose in the Blood Diabetes means y...  NIHSeniorHealth
# 51  Diabetes is a serious, life-long disease. It c...  NIHSeniorHealth
# 52  The two most common forms of diabetes are type...  NIHSeniorHealth
# 53  Diabetes is often called a "silent" disease be...  NIHSeniorHealth
# 54  Diabetes cannot be cured, but it can be manage...  NIHSeniorHealth
# 55  Type 1 diabetes is an autoimmune disease. In a...  NIHSeniorHealth
#
#    focus_area                                            combine  \
# 50   Diabetes  What is (are) Diabetes ? Too Much Glucose in t...
# 51   Diabetes  Who is at risk for Diabetes? ? Diabetes is a s...
# 52   Diabetes  How to prevent Diabetes ? The two most common ...
# 53   Diabetes  What are the symptoms of Diabetes ? Diabetes i...
# 54   Diabetes  What are the treatments for Diabetes ? Diabete...
# 55   Diabetes  What causes Diabetes ? Type 1 diabetes is an a...
#
#                                         diabetes_info  \
# 50  ['Diabetes', 'Much', 'Glucose', 'Blood', 'Diab...
# 51  ['risk', 'Diabetes', 'Diabetes', 'serious', 'd...
# 52  ['prevent', 'Diabetes', 'two', 'common', 'form...
# 53  ['symptoms', 'Diabetes', 'Diabetes', 'often', ...
# 54  ['treatments', 'Diabetes', 'Diabetes', 'cured'...
# 55  ['causes', 'Diabetes', 'Type', 'diabetes', 'au...
#
#                                   diabetes_lemmatized
# 50  [['Diabetes',, 'Much',, 'Glucose',, 'Blood',, ...
# 51  [['risk',, 'Diabetes',, 'Diabetes',, 'serious'...
# 52  [['prevent',, 'Diabetes',, 'two',, 'common',, ...
# 53  [['symptoms',, 'Diabetes',, 'Diabetes',, 'ofte...
# 54  [['treatments',, 'Diabetes',, 'Diabetes',, 'cu...
# 55  [['causes',, 'Diabetes',, 'Type',, 'diabetes',...

# %%
diabetes_result_df = df_diabetes.drop_duplicates(subset=['diabetes_lemmatized'], keep='first')
print(diabetes_result_df)
# Out:
#                                   question  \
# 50                What is (are) Diabetes ?
# 51          Who is at risk for Diabetes? ?
# 52               How to prevent Diabetes ?
# 53     What are the symptoms of Diabetes ?
# 54  What are the treatments for Diabetes ?
# 55                  What causes Diabetes ?
#
#                                                answer           source  \
# 50  Too Much Glucose in the Blood Diabetes means y...  NIHSeniorHealth
# 51  Diabetes is a serious, life-long disease. It c...  NIHSeniorHealth
# 52  The two most common forms of diabetes are type...  NIHSeniorHealth
# 53  Diabetes is often called a "silent" disease be...  NIHSeniorHealth
# 54  Diabetes cannot be cured, but it can be manage...  NIHSeniorHealth
# 55  Type 1 diabetes is an autoimmune disease. In a...  NIHSeniorHealth
#
#    focus_area                                            combine  \
# 50   Diabetes  What is (are) Diabetes ? Too Much Glucose in t...
# 51   Diabetes  Who is at risk for Diabetes? ? Diabetes is a s...
# 52   Diabetes  How to prevent Diabetes ? The two most common ...
# 53   Diabetes  What are the symptoms of Diabetes ? Diabetes i...
# 54   Diabetes  What are the treatments for Diabetes ? Diabete...
# 55   Diabetes  What causes Diabetes ? Type 1 diabetes is an a...
#
#                                         diabetes_info  \
# 50  ['Diabetes', 'Much', 'Glucose', 'Blood', 'Diab...
# 51  ['risk', 'Diabetes', 'Diabetes', 'serious', 'd...
# 52  ['prevent', 'Diabetes', 'two', 'common', 'form...
# 53  ['symptoms', 'Diabetes', 'Diabetes', 'often', ...
# 54  ['treatments', 'Diabetes', 'Diabetes', 'cured'...
# 55  ['causes', 'Diabetes', 'Type', 'diabetes', 'au...
#
#                                   diabetes_lemmatized
# 50  [['Diabetes',, 'Much',, 'Glucose',, 'Blood',, ...
# 51  [['risk',, 'Diabetes',, 'Diabetes',, 'serious'...
# 52  [['prevent',, 'Diabetes',, 'two',, 'common',, ...
# 53  [['symptoms',, 'Diabetes',, 'Diabetes',, 'ofte...
# 54  [['treatments',, 'Diabetes',, 'Diabetes',, 'cu...
# 55  [['causes',, 'Diabetes',, 'Type',, 'diabetes',...

# %%
# Convert the lists to strings
diabetes_result_df['diabetes_lemmatized'] = diabetes_result_df['diabetes_lemmatized'].apply(lambda x: ' '.join(x))

# %%
diabetes_result_df['index'] = diabetes_result_df.index
diabetes_result_df
# Out:
#                                   question  \
# 50                What is (are) Diabetes ?
# 51          Who is at risk for Diabetes? ?
# 52               How to prevent Diabetes ?
# 53     What are the symptoms of Diabetes ?
# 54  What are the treatments for Diabetes ?
# 55                  What causes Diabetes ?
#
#                                                answer           source  \
# 50  Too Much Glucose in the Blood Diabetes means y...  NIHSeniorHealth
# 51  Diabetes is a serious, life-long disease. It c...  NIHSeniorHealth
# 52  The two most common forms of diabetes are type...  NIHSeniorHealth
# 53  Diabetes is often called a "silent" disease be...  NIHSeniorHealth
# 54  Diabetes cannot be cured, but it can be manage...  NIHSeniorHealth
# 55  Type 1 diabetes is an autoimmune disease. In a...  NIHSeniorHealth
#
#    focus_area                                            combine  \
# 50   Diabetes  What is (are) Diabetes ? Too Much Glucose in t...
# 51   Diabetes  Who is at risk for Diabetes? ? Diabetes is a s...
# 52   Diabetes  How to prevent Diabetes ? The two most common ...
# 53   Diabetes  What are the symptoms of Diabetes ? Diabetes i...
# 54   Diabetes  What are the treatments for Diabetes ? Diabete...
# 55   Diabetes  What causes Diabetes ? Type 1 diabetes is an a...
#
#                                         diabetes_info  \
# 50  ['Diabetes', 'Much', 'Glucose', 'Blood', 'Diab...
# 51  ['risk', 'Diabetes', 'Diabetes', 'serious', 'd...
# 52  ['prevent', 'Diabetes', 'two', 'common', 'form...
# 53  ['symptoms', 'Diabetes', 'Diabetes', 'often', ...
# 54  ['treatments', 'Diabetes', 'Diabetes', 'cured'...
# 55  ['causes', 'Diabetes', 'Type', 'diabetes', 'au...
#
#                                   diabetes_lemmatized  index
# 50  ['Diabetes', 'Much', 'Glucose', 'Blood', 'Diab...     50
# 51  ['risk', 'Diabetes', 'Diabetes', 'serious', 'd...     51
# 52  ['prevent', 'Diabetes', 'two', 'common', 'form...     52
# 53  ['symptoms', 'Diabetes', 'Diabetes', 'often', ...     53
# 54  ['treatments', 'Diabetes', 'Diabetes', 'cured'...     54
# 55  ['causes', 'Diabetes', 'Type', 'diabetes', 'au...     55

# %%
# Print rows with empty documents for diabetes
print("Empty documents in diabetes:")
print(diabetes_result_df[diabetes_result_df['diabetes_lemmatized'].apply(lambda x: len(x)) == 0])
# Out:
# Empty documents in diabetes:
# Empty DataFrame
# Columns: [question, answer, source, focus_area, combine, diabetes_info, diabetes_lemmatized, index]
# Index: []

# %%
diabetes_final = pd.DataFrame(data = diabetes_result_df['diabetes_lemmatized'])
diabetes_final
# Out:
#                                   diabetes_lemmatized
# 50  ['Diabetes', 'Much', 'Glucose', 'Blood', 'Diab...
# 51  ['risk', 'Diabetes', 'Diabetes', 'serious', 'd...
# 52  ['prevent', 'Diabetes', 'two', 'common', 'form...
# 53  ['symptoms', 'Diabetes', 'Diabetes', 'often', ...
# 54  ['treatments', 'Diabetes', 'Diabetes', 'cured'...
# 55  ['causes', 'Diabetes', 'Type', 'diabetes', 'au...

# %%
#find similarity between glaucoma and diabetes
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Function to calculate Jaccard similarity
def jaccard_similar(list1, list2):
    intersection = len(set(list1).intersection(list2))
    union = len(set(list1).union(list2))
    return intersection / union if union != 0 else 0

# Function to calculate Jaccard similarity between rows of two DataFrames
def calculate_similar(df1, df2):
    similarities = []

    for index1, row1 in df1.iterrows():
        for index2, row2 in df2.iterrows():
            sim = jaccard_similar(row1['glaucoma_lemmatized'], row2['diabetes_lemmatized'])
            similarities.append((index1, index2, sim))

    return similarities


similarities = calculate_similar(glaucoma_final, diabetes_final)

# Displaying the results
for idx1, idx2, sim in similarities:
    print(f"Similarity between row {idx1} in glaucoma and row {idx2} in diabetes: {sim}")
# Out:
# Similarity between row 0 in glaucoma and row 50 in diabetes: 0.8846153846153846
# Similarity between row 0 in glaucoma and row 51 in diabetes: 0.9
# Similarity between row 0 in glaucoma and row 52 in diabetes: 0.8867924528301887
# Similarity between row 0 in glaucoma and row 53 in diabetes: 0.84
# Similarity between row 0 in glaucoma and row 54 in diabetes: 0.9056603773584906
# Similarity between row 0 in glaucoma and row 55 in diabetes: 0.66
# Similarity between row 1 in glaucoma and row 50 in diabetes: 0.7142857142857143
# Similarity between row 1 in glaucoma and row 51 in diabetes: 0.8
# Similarity between row 1 in glaucoma and row 52 in diabetes: 0.6862745098039216
# Similarity between row 1 in glaucoma and row 53 in diabetes: 0.7727272727272727
# Similarity between row 1 in glaucoma and row 54 in diabetes: 0.7058823529411765
# Similarity between row 1 in glaucoma and row 55 in diabetes: 0.8157894736842105
# Similarity between row 2 in glaucoma and row 50 in diabetes: 0.6938775510204082
# Similarity between row 2 in glaucoma and row 51 in diabetes: 0.7391304347826086
# Similarity between row 2 in glaucoma and row 52 in diabetes: 0.6666666666666666
# Similarity between row 2 in glaucoma and row 53 in diabetes: 0.7111111111111111
# Similarity between row 2 in glaucoma and row 54 in diabetes: 0.6538461538461539
# Similarity between row 2 in glaucoma and row 55 in diabetes: 0.8378378378378378
# Similarity between row 3 in glaucoma and row 50 in diabetes: 0.8571428571428571
# Similarity between row 3 in glaucoma and row 51 in diabetes: 0.8723404255319149
# Similarity between row 3 in glaucoma and row 52 in diabetes: 0.8235294117647058
# Similarity between row 3 in glaucoma and row 53 in diabetes: 0.8085106382978723
# Similarity between row 3 in glaucoma and row 54 in diabetes: 0.8076923076923077
# Similarity between row 3 in glaucoma and row 55 in diabetes: 0.6888888888888889
# Similarity between row 4 in glaucoma and row 50 in diabetes: 0.7083333333333334
# Similarity between row 4 in glaucoma and row 51 in diabetes: 0.6808510638297872
# Similarity between row 4 in glaucoma and row 52 in diabetes: 0.68
# Similarity between row 4 in glaucoma and row 53 in diabetes: 0.7674418604651163
# Similarity between row 4 in glaucoma and row 54 in diabetes: 0.6666666666666666
# Similarity between row 4 in glaucoma and row 55 in diabetes: 0.8108108108108109
# Similarity between row 5 in glaucoma and row 50 in diabetes: 0.6666666666666666
# Similarity between row 5 in glaucoma and row 51 in diabetes: 0.6739130434782609
# Similarity between row 5 in glaucoma and row 52 in diabetes: 0.64
# Similarity between row 5 in glaucoma and row 53 in diabetes: 0.6444444444444445
# Similarity between row 5 in glaucoma and row 54 in diabetes: 0.6274509803921569
# Similarity between row 5 in glaucoma and row 55 in diabetes: 0.8571428571428571
# Similarity between row 6 in glaucoma and row 50 in diabetes: 0.6666666666666666
# Similarity between row 6 in glaucoma and row 51 in diabetes: 0.7111111111111111
# Similarity between row 6 in glaucoma and row 52 in diabetes: 0.64
# Similarity between row 6 in glaucoma and row 53 in diabetes: 0.7209302325581395
# Similarity between row 6 in glaucoma and row 54 in diabetes: 0.6274509803921569
# Similarity between row 6 in glaucoma and row 55 in diabetes: 0.8055555555555556

# %%
#plotting the similarities between glaucoma and diabetes
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a DataFrame from the list of similarities
similarity_df = pd.DataFrame(similarities, columns=['Index1', 'Index2', 'Similarity'])

# Reshape the DataFrame to create a similarity matrix
similarity_matrix = similarity_df.pivot(index='Index1', columns='Index2', values='Similarity')

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(similarity_matrix, annot=True, fmt=".2f", linewidths=.5, cbar_kws={'label': 'Jaccard Similarity'})
plt.title('Glaucoma & Diabetes Similarity Heatmap')
plt.xlabel('Diabetes index')
plt.ylabel('Glaucoma index')
plt.show()

# %% [markdown]
# # From the above graph we can see that the highly correlated rows are:
# row 0 (glaucoma) and row 54 (diabetes)\
# row 0 (glaucoma) and row 51 (diabetes)\
# row 0 (glaucoma) and row 52 (diabetes)\
# row 0 (glaucoma) and row 50 (diabetes)\
# row 1 (glaucoma) and row 55 (diabetes)\
# row 2 (glaucoma) and row 55 (diabetes)\
# row 3 (glaucoma) and row 51 (diabetes)\
# row 5 (glaucoma) and row 55 (diabetes)

# %% [markdown]
# Hence, we can say that diabetes and glaucoma are highly correlated and similar to each other. A patient having diabetes can increase his/ her chance of developing glaucoma.
